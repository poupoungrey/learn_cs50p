# %% [markdown]
# # Lecture 1

# %%
print(
    'bye planet'
)

print(int(10000))
print(f"{10000:,}")
# Out:
# bye planet

# %% [markdown]
# # Lecture 2

# %%
x = 4
y = 9

print(x / y)
print(x % y)
# Out:
# 0.4444444444444444
# 4
